# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(40)
data=pd.DataFrame({
    'Feature1':np.random.rand(100),
    'Fearture2':np.random.rand(100)*2,
    'Feature3':np.random.rand(100)*3,
    'Feature4':np.random.rand(100)*4,
    'Feature5':np.random.rand(100)*5,
    'Feature6':np.random.rand(100)*6
})

#Calucation of the Correleation matrix
corr_matrix=data.corr()

plt.figure(figsize=(4,7))
heatmap=sns.heatmap(corr_matrix,annot=True,cmap="coolwarm",center=0)
plt.title("Correlation of Heatmap")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

np.random.seed(40)
X=3*np.random.rand(99,2)
y=5+3*x+np.random.rand(99,2)

data=pd.DataFrame({'Feature':X.flatten(),'Target':y.flatten()})

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=41)
model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)


plt.figure(figsize=(7,7))
plt.scatter(X_test,y_test,color='blue', label='Actual data')
plt.plot(X_test,y_test,color="red",linewidth=2,label ="Reggression Line")
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title("Linear Reggression Analysis")
plt.legend()
plt.show()

print("Intercept (b0):",model.intercept_[0])
print("Slope (b1):",model.coef_[0][0])

mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Squared Error:",mse)
print("R_squared:",r2)
# Out:
# Intercept (b0): 5.471943166095644
# Slope (b1): 2.959961397865731
# Mean Squared Error: 0.07842166133963782
# R_squared: 0.9883392634283159
