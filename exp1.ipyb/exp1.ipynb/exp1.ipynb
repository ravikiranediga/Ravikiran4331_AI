# %%
import pandas as pd

# %%
labels=['a','b','c','d','e']
data=[10,20,30,40,50]
Series_with_labels=pd.Series(data,index=labels)
print("Roll No:23G01A4331")
print("Pandas Series with Labels:")
print(Series_with_labels)
type(Series_with_labels)
# Out:
# Roll No:23G01A4331
# Pandas Series with Labels:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# pandas.core.series.Series

# %%
data_dict={"a":100,"b":200,"c":300,"d":400,"e":500}
Series_from_dict=pd.Series(data_dict)
print("Roll No:23G01A4331")
print("\nPandas Series from Dictionary:")
print(Series_from_dict)
# Out:
# Roll No:23G01A4331
#
# Pandas Series from Dictionary:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
data_dict_df={
   "Name":["Ravi","Kiran","Daaku","Devara","Pushpa","Kesava"],
   "Age":[22,30,21,20,23,32],
   "Salary":[50000,60000,70000,80000,55000,45000]
}
print("Roll No:23G01A4331")
df= pd.DataFrame(data_dict_df)
print("\nPandas DataFrame:")
print(df)
type(data_dict_df)
# Out:
# Roll No:23G01A4331
#
# Pandas DataFrame:
#      Name  Age  Salary
# 0    Ravi   22   50000
# 1   Kiran   30   60000
# 2   Daaku   21   70000
# 3  Devara   20   80000
# 4  Pushpa   23   55000
# 5  Kesava   32   45000
# dict

# %%
df.describe()
# Out:
#              Age       Salary
# count   6.000000      6.00000
# mean   24.666667  60000.00000
# std     5.046451  13038.40481
# min    20.000000  45000.00000
# 25%    21.250000  51250.00000
# 50%    22.500000  57500.00000
# 75%    28.250000  67500.00000
# max    32.000000  80000.00000

# %%
df.head()
# Out:
#      Name  Age  Salary
# 0    Ravi   22   50000
# 1   Kiran   30   60000
# 2   Daaku   21   70000
# 3  Devara   20   80000
# 4  Pushpa   23   55000

# %%
df.head(3)
# Out:
#     Name  Age  Salary
# 0   Ravi   22   50000
# 1  Kiran   30   60000
# 2  Daaku   21   70000

# %%
df.tail()
# Out:
#      Name  Age  Salary
# 1   Kiran   30   60000
# 2   Daaku   21   70000
# 3  Devara   20   80000
# 4  Pushpa   23   55000
# 5  Kesava   32   45000

# %%
df.tail(2)
# Out:
#      Name  Age  Salary
# 4  Pushpa   23   55000
# 5  Kesava   32   45000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Salary  6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes

# %%
import  pandas as pd

# %%
data_dict_df={
   "Name":["Ravi","Kiran","Daaku","Devara","Pushpa","Kesava"],
   "Age":[22,30,21,20,23,32],
   "Salary":[50000,60000,70000,80000,55000,45000]
}
print("Roll No:23G01A4331")
df= pd.DataFrame(data_dict_df)
df
# Out:
# Roll No:23G01A4331
#      Name  Age  Salary
# 0    Ravi   22   50000
# 1   Kiran   30   60000
# 2   Daaku   21   70000
# 3  Devara   20   80000
# 4  Pushpa   23   55000
# 5  Kesava   32   45000

# %%
print("Roll No:23G01A4331")
df.plot(kind='bar',x='Name',y='Salary',title='Bar Plot')
# Out:
# Roll No:23G01A4331
# <Axes: title={'center': 'Bar Plot'}, xlabel='Name'>

# %%
print("Roll No:23G01A4331")
df['Age'].plot(kind='hist',title='Histogram')
# Out:
# Roll No:23G01A4331
# <Axes: title={'center': 'Histogram'}, ylabel='Frequency'>

# %%
print("Roll No:23G01A4331")
df.plot(kind='line',x='Name',y='Salary',title='Line Plot')
# Out:
# Roll No:23G01A4331
# <Axes: title={'center': 'Line Plot'}, xlabel='Name'>

# %%
print("Roll No:23G01A4331")
df.plot(kind='scatter',x='Age',y='Salary',title='Scatter Plot')
# Out:
# Roll No:23G01A4331
# <Axes: title={'center': 'Scatter Plot'}, xlabel='Age', ylabel='Salary'>
