# %%
import pandas as pd

# %%
pd.read_html('https://www.basketball-reference.com/teams/NYK/2025.html')
# Out:
# [     No.                   Player Pos   Ht   Wt          Birth Date  Birth  \
#  0   25.0            Mikal Bridges  SF  6-6  209     August 30, 1996  us US
#  1   11.0            Jalen Brunson  PG  6-2  190     August 31, 1996  us US
#  2    3.0                Josh Hart  SG  6-4  215       March 6, 1995  us US
#  3    8.0               OG Anunoby  PF  6-7  232       July 17, 1997  gb GB
#  4    1.0            Cameron Payne  PG  6-3  183      August 8, 1994  us US
#  5   32.0       Karl-Anthony Towns   C  7-0  248   November 15, 1995  us US
#  6    2.0            Miles McBride  PG  6-2  200   September 8, 2000  us US
#  7    5.0         Precious Achiuwa   C  6-8  225  September 19, 1999  ng NG
#  8   44.0            Landry Shamet  SG  6-4  190      March 13, 1997  us US
#  9   13.0              Tyler Kolek  PG  6-1  195      March 27, 2001  us US
#  10  55.0           Ariel Hukporti   C  7-0  246      April 11, 2002  de DE
# ...

# %%
pip install lxml
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 660.9 kB/s eta 0:00:05
#    ----- ---------------------------------- 0.5/3.8 MB 660.9 kB/s eta 0:00:05
#    -------- ------------------------------- 0.8/3.8 MB 679.7 kB/s eta 0:00:05
#    -------- ------------------------------- 0.8/3.8 MB 679.7 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.8 MB 638.7 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.8 MB 638.7 kB/s eta 0:00:05
#    ------------- -------------------------- 1.3/3.8 MB 614.0 kB/s eta 0:00:05
#    ------------- -------------------------- 1.3/3.8 MB 614.0 kB/s eta 0:00:05
# ...

# %%
import pandas as pd

# %%
hi=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
hi
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
hi.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
hi['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
len(hi)
# Out:
# 891

# %%
hi.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
(len(hi['Sex'][hi['Sex']=='male']))
# Out:
# 577

# %%
(hi['Sex']=='male').value_counts()
# Out:
# Sex
# True     577
# False    314
# Name: count, dtype: int64

# %%
(hi['Sex'][hi['Survived']==1])
# Out:
# 1      female
# 2      female
# 3      female
# 8      female
# 9      female
#         ...
# 875    female
# 879    female
# 880    female
# 887    female
# 889      male
# Name: Sex, Length: 342, dtype: object

# %%
(hi['Sex'][hi['Survived']==0])
# Out:
# 0        male
# 4        male
# 5        male
# 6        male
# 7        male
#         ...
# 884      male
# 885    female
# 886      male
# 888    female
# 890      male
# Name: Sex, Length: 549, dtype: object

# %%
x=hi[['Survived']=='0'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 x=hi[['Survived']=='0'].value_counts()
#
# ...

# %%
print(x)
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
hi[''].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Casuality'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 hi['Casuality'].value_counts()
#
# ...

# %%
(hi['Age'][hi['Age']>=25])
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 6      54.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 436, dtype: float64

# %%
hi[hi['Age']==hi['Age'].min()]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %%
hi[hi['Age']==hi['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
hi['PassengerId'][hi['PassengerId']=='ticket']
# Out:
# Series([], Name: PassengerId, dtype: int64)

# %%
hi['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
#Difference in survival based on class

(class_survival = hi.groupby('Ticket').sum()['Survived']==2)
class_survival
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[174], line 3
#       1 #Difference in survival based on class
# ----> 3 len(class_survival = hi.groupby('Ticket').sum()['Survived']==2)
#       4 class_survival
#
# TypeError: len() takes no keyword arguments

# %%
hi['PassengerId'][hi['Ticket'==0]].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[185], line 1
# ...

# %%
hi['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
len(hi['Name'][hi['Name']=='s'])
# Out:
# 0

# %%
hi['Name'].str

# %%
(hi['Name'].str.startswith('S'))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
len(hi[hi['Name'].str.startswith('S')])
# Out:
# 86

# %%
import pandas as pd

# %%
pd.read_csv('https://archive.ics.uci.edu/dataset/222/bank+marketing.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[226], line 1
# ----> 1 pd.read_csv('https://archive.ics.uci.edu/dataset/222/bank+marketing.csv')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
